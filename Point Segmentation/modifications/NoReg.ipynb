# %%
import torch
from torch import optim
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
# from torchvision.transforms import ToTensorfrom
from torch.utils.tensorboard import SummaryWriter

import matplotlib.pyplot as plt
import numpy as np
import os

from scipy.spatial import KDTree

# %%
class KDTreeDataset(Dataset):
    def __init__(self, pts_file, split=0):
        points = np.loadtxt(pts_file, delimiter=' ')
        points = np.delete(points, -2, 1)
        points = np.delete(points, -2, 1)
        # points = np.delete(points, -2, 1)

        if split == 1:
            points = points[:len(points)//2]
        elif split == 2:
            points = points[len(points)//2:]

        print('file points shape', points.shape)
        
        self.dim_scalars = []
        for i in range(4):
            dim_min, dim_max = min(points[:,i]), max(points[:,i])
            points[:,i] = (points[:,i] - dim_min) / (dim_max - dim_min)
            self.dim_scalars.append(dim_max - dim_min)
        self.data = points

        self.tree = KDTree(self.data[:, :3])
        
    def __len__(self):
        return len(self.data) // 15000
        
    def __getitem__(self, idx):
        # Return batches of 25000 points
        # print('Starting point', self.data[idx * 10000, :3])
        noisy_point = self.data[idx * 15000, :3] + np.random.normal(0, 0.01, 3)[0]
        # print('Noisy point', noisy_point)
        
        _, indicies = self.tree.query(noisy_point, k=25000)

        xyzirn = self.data[indicies, :-1]  # x, y, z, ***intensity, return number, number of returns***
        label = self.data[indicies, -1] == 5

        xyzirn = torch.from_numpy(xyzirn.T).float() # intensity, z, y, x from top to bottom? or other way around
        label = torch.tensor(label).long()
        
        # print(xyzirn.size(), label.size())

        return xyzirn, label

class NormalDataset(Dataset):
    def __init__(self, pts_file, split=0):
        points = np.loadtxt(pts_file, delimiter=' ')
        points = np.delete(points, -2, 1)
        points = np.delete(points, -2, 1)
        # points = np.delete(points, -2, 1)

        if split == 1:
            points = points[:len(points)//2]
        elif split == 2:
            points = points[len(points)//2:]

        print(points.shape)
        # do i need to min max intensity, return number, number of returns, etc.? probably not
        self.dim_scalars = []
        for i in range(4):
            dim_min, dim_max = min(points[:,i]), max(points[:,i])
            points[:,i] = (points[:,i] - dim_min) / (dim_max - dim_min)
            self.dim_scalars.append(dim_max - dim_min)
        self.data = points
        
    def __len__(self):
        return len(self.data) // 25000
        
    def __getitem__(self, idx):
        # Return batches of 25000 points
        xyzirn = self.data[idx * 25000: (idx + 1) * 25000, :-1]  # x, y, z, ***intensity, return number, number of returns***
        label = self.data[idx * 25000: (idx + 1) * 25000, -1] == 5

        xyzirn = torch.from_numpy(xyzirn.T).float() # intensity, z, y, x from top to bottom
        label = torch.tensor(label).long()
        
        return xyzirn, label


data_folder = os.path.join(os.getcwd(), r"data\Point Cloud")
training_data = KDTreeDataset(os.path.join(data_folder, r"Traininig.pts"))
validation_data = NormalDataset(os.path.join(data_folder, r"Testing.pts"), split=1)
testing_data = NormalDataset(os.path.join(data_folder, r"Testing.pts"), split=2)
train_dataloader = DataLoader(training_data, batch_size=5, shuffle=True) # can/should i use shuffle, try lowering it?
validation_dataloader = DataLoader(validation_data, batch_size=5, shuffle=False)
test_dataloader = DataLoader(testing_data, batch_size=5, shuffle=False)

num_classes = 2
# Out:
# file points shape (753876, 5)
# (205861, 5)
# (205861, 5)

# %%
print(len(training_data))
print(len(train_dataloader))
# Out:
# 50
# 10

# %%
for i, data in enumerate(train_dataloader):
    print(data[0].size())
# Out:
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])

# %%
import open3d as o3d
import numpy as np
import copy
from collections import Counter

def plot_view(entire_view = True):
    # Assuming pc is your point cloud data, in shape (N, 3)
    pc_num = 2

    if entire_view:
        pc = training_data.data[:, :3]
        labels = training_data.data[:, -1] == 5
    else:
        pc, labels = training_data[pc_num]
        pc = pc.T.numpy()[:, :3]
        labels = labels.numpy()

    pc = copy.deepcopy(pc)
    for i in range(3):
        pc[:, i] *= training_data.dim_scalars[i]

    print(Counter(labels), len(labels))

    # Define colors for each label
    color_map = {0: [0.5, 0.5, 0.5],  # Gray color for label 0
                1: [1.0, 0.0, 0.0]}  # Red color for label 1

    # Map each label to a color
    colors = np.array([color_map[label] for label in labels])

    # Create point cloud
    point_cloud = o3d.geometry.PointCloud()
    point_cloud.points = o3d.utility.Vector3dVector(pc)
    point_cloud.colors = o3d.utility.Vector3dVector(colors)

    # Visualize the point cloud
    o3d.visualization.draw_geometries([point_cloud])
# plot_view(entire_view = False)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
def plot_batch(data, labels):
    pc, labels = data.transpose(1,2).reshape(-1, 4).numpy()[:, :3], labels.view(-1).numpy()
    # print(labels.shape)
    pc = copy.deepcopy(pc)
    for i in range(3):
        pc[:, i] *= training_data.dim_scalars[i]

    print(Counter(list(labels)), len(labels))

    # Define colors for each label
    color_map = {0: [0.5, 0.5, 0.5],  # Gray color for label 0
                1: [1.0, 0.0, 0.0]}  # Red color for label 1

    # Map each label to a color
    colors = np.array([color_map[label] for label in labels])

    # Create point cloud
    point_cloud = o3d.geometry.PointCloud()
    point_cloud.points = o3d.utility.Vector3dVector(pc)
    point_cloud.colors = o3d.utility.Vector3dVector(colors)

    # Visualize the point cloud
    o3d.visualization.draw_geometries([point_cloud])
# for i, data in enumerate(train_dataloader):
#     print(data[0].size())
#     plot_batch(*data)
#     break

# %%
# Get cpu, gpu or mps device for training.\
try:
    device = (
        "cuda"
        if torch.cuda.is_available()
        else "mps"
        if torch.backends.mps.is_available()
        else "cpu"
    )
except:
    device = 'cpu'
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
class STNkd(nn.Module):
    def __init__(self, k=64):
        super(STNkd, self).__init__()
        self.mlp1 = nn.Sequential(torch.nn.Conv1d(k, 64, 1), nn.Identity(64), nn.GELU())
        self.mlp2 = nn.Sequential(torch.nn.Conv1d(64, 128, 1), nn.Identity(128), nn.GELU())
        self.mlp3 = nn.Sequential(torch.nn.Conv1d(128, 1024, 1), nn.Identity(1024), nn.GELU())
        self.mlp4 = nn.Sequential(nn.Linear(1024, 512), nn.Identity(512), nn.GELU())
        self.mlp5 = nn.Sequential(nn.Linear(512, 256), nn.Identity(256), nn.GELU())
        self.fc = nn.Linear(256, k*k)

        self.k = k

    def forward(self, x):
        batchsize = x.size()[0]
        x = self.mlp1(x)
        x = self.mlp2(x)
        x = self.mlp3(x)

        x = torch.max(x, 2, keepdim=True)[0]
        x = x.view(-1, 1024)

        x = self.mlp4(x)
        x = self.mlp5(x)
        x = self.fc(x)

        iden = torch.eye(self.k, requires_grad=True).repeat(batchsize,1,1)
        if x.is_cuda:
            iden = iden.cuda()
        x = x.view(-1, self.k, self.k) + iden

        return x
    
class PoinNet(nn.Module):
    def __init__(self, input_dim=6, num_classes=2):
        super().__init__()

        # Should GELU be after LayerNorm?
        self.stn1 = STNkd(k=input_dim)
        self.mlp1 = nn.Sequential(nn.Conv1d(input_dim, 64, kernel_size=1), nn.Identity(64), nn.GELU())
        self.mlp2 = nn.Sequential(nn.Conv1d(64, 64, kernel_size=1), nn.Identity(64), nn.GELU())
        
        self.stn2 = STNkd(k=64)
        self.mlp3 = nn.Sequential(nn.Conv1d(64, 64, kernel_size=1), nn.Identity(64), nn.GELU())
        self.mlp4 = nn.Sequential(nn.Conv1d(64, 128, kernel_size=1), nn.Identity(128), nn.GELU())
        self.mlp5 = nn.Sequential(nn.Conv1d(128, 1024, kernel_size=1), nn.Identity(1024), nn.GELU())
        
        self.mlp6 = nn.Sequential(nn.Linear(1088, 512), nn.Identity(512), nn.GELU())
        self.mlp7 = nn.Sequential(nn.Linear(512, 256), nn.Identity(256), nn.GELU())
        self.mlp8 = nn.Sequential(nn.Linear(256, 128), nn.Identity(128), nn.GELU())
        self.fc = nn.Linear(128, num_classes)

        self.debug = nn.Conv1d(input_dim, num_classes, 1)

    def forward(self, x):
        n_pts = x.size()[2]

        trans6x6 = self.stn1(x) 
        x = x.transpose(2, 1)
        x = torch.bmm(x, trans6x6)
        x = x.transpose(2, 1)

        x = self.mlp1(x)
        # print(1, x.size())
        x = self.mlp2(x)
        # print(2, x.size())
        
        
        trans64x64 = self.stn2(x)
        x = x.transpose(2, 1)
        x = torch.bmm(x, trans64x64)
        local_features = x.transpose(2, 1)
        
        x = self.mlp3(local_features)
        # print(3, x.size())
        x = self.mlp4(x)
        # print(4, x.size())
        x = self.mlp5(x)
        # print(5, x.size())
        x = torch.max(x, 2)[0]
        # print(6, x.size())
        
        # FOR CLASSIFICATION
        # x = self.mlp6(x)
        # print(6, x.size())
        # x = self.mlp7(x)
        # print(7, x.size())
        # x = self.fc(x)
        # print(8, x.size())
        # return F.log_softmax(x, dim=1)

        global_features = x.unsqueeze(2).repeat(1, 1, n_pts)
        # print(7, global_features.size())
        x = torch.cat([local_features, global_features], 1)
        # print(8, x.size())

        x = x.transpose(2, 1)
        x = self.mlp6(x)
        # print(9, x.size())
        x = self.mlp7(x)
        # print(10, x.size())
        x = self.mlp8(x)
        # print(11, x.size())
        x = self.fc(x)
        # print(12, x.size())

        # x = x.view(-1, 2)
        # print(13, x.size())
        x = F.log_softmax(x, dim=-1)
        # print(14, x.size())

        return x, trans64x64

# model = PoinNet(input_dim=6, num_classes=2).to(device)

# %%
def feature_transform_regularizer(trans):
    d = trans.size(1)
    I = torch.eye(d).unsqueeze(0).to(device)
    loss = torch.linalg.norm(I - torch.bmm(trans, trans.transpose(2,1)), dim=(1,2))
    loss = torch.mean(loss)
    return loss

# %% [markdown]
# ## Online Code

# %%
from sklearn.metrics import f1_score
from collections import Counter


writer = SummaryWriter()
classifier = PoinNet(input_dim=4, num_classes=2).to(device)

optimizer = optim.Adam(classifier.parameters(), lr=0.0005, betas=(0.9, 0.999))

num_batch = len(training_data)

for epoch in range(120):
    classifier.train()
    train_loss, train_f1, train_acc = 0.0, 0.0, 0.0
    predictions, labels = np.array([]), np.array([])
    for i, data in enumerate(train_dataloader, 1):
        points, target = data
        points, target = points.to(device), target.to(device)
        optimizer.zero_grad()
        pred, trans_feat = classifier(points)
        pred = pred.view(-1, num_classes)
        target = target.view(-1, 1).squeeze()
        print(f'Iteration {i}', pred.size(), target.size())

        loss = F.nll_loss(pred, target)
        loss += feature_transform_regularizer(trans_feat) * 0.001
        loss.backward()
        optimizer.step()
        train_loss += float(loss) # JUST USING LOSS ACCUMULATES HISTORY

        predictions = np.append(predictions, pred.max(1)[1].cpu())
        labels = np.append(labels, target.cpu())

    train_f1 = f1_score(predictions, labels)
    train_acc = sum(predictions == labels)/float(len(labels))
    train_loss /= len(train_dataloader)


    classifier.eval()
    valid_loss, valid_f1, valid_acc = 0.0, 0.0, 0.0
    predictions, labels = np.array([]), np.array([])
    with torch.no_grad():
        for i, data in enumerate(validation_dataloader):
            points, target = data
            points, target = points.to(device), target.to(device)
            pred,  trans_feat = classifier(points)
            pred = pred.view(-1, num_classes)
            target = target.view(-1, 1).squeeze()

            loss = F.nll_loss(pred, target)
            loss += feature_transform_regularizer(trans_feat) * 0.001
            valid_loss += float(loss)

            predictions = np.append(predictions, pred.max(1)[1].cpu())
            labels = np.append(labels, target.cpu())

    valid_f1 = f1_score(predictions, labels)
    valid_acc = sum(predictions == labels)/float(len(labels))
    valid_loss /= len(validation_dataloader)


    writer.add_scalars('losses', {'training':train_loss, 'validation':valid_loss}, global_step=epoch)
    writer.add_scalars('f1 scores', {'training':train_f1, 'validation':valid_f1}, global_step=epoch)

    print(f'[{epoch}] train loss: {train_loss} accuracy: {train_acc} f1 score: {train_f1}')
    print(f'[{epoch}] validation loss: {valid_loss} accuracy: {valid_acc} f1 score: {valid_f1}')
    print()

writer.flush()
writer.close()
# Out:
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [0] train loss: 0.5946170866489411 accuracy: 0.8732592 f1 score: 0.0
# [0] validation loss: 0.6296709179878235 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [1] train loss: 0.461895814538002 accuracy: 0.873472 f1 score: 0.0
# [1] validation loss: 0.6532093286514282 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [2] train loss: 0.38458782583475115 accuracy: 0.8775464 f1 score: 0.0
# [2] validation loss: 0.6502301692962646 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [3] train loss: 0.38268562853336335 accuracy: 0.8752592 f1 score: 0.0
# [3] validation loss: 0.6671167612075806 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [4] train loss: 0.37670975625514985 accuracy: 0.8766048 f1 score: 0.0
# [4] validation loss: 0.7092965245246887 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [5] train loss: 0.37497759610414505 accuracy: 0.8771032 f1 score: 0.0
# [5] validation loss: 0.7073534429073334 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [6] train loss: 0.37216756939888 accuracy: 0.8787792 f1 score: 0.0
# [6] validation loss: 0.7101589739322662 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [7] train loss: 0.3760406017303467 accuracy: 0.8762104 f1 score: 0.0
# [7] validation loss: 0.7013800144195557 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [8] train loss: 0.3827074557542801 accuracy: 0.8721184 f1 score: 0.0
# [8] validation loss: 0.6735011637210846 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [9] train loss: 0.3872897505760193 accuracy: 0.8742376 f1 score: 0.0
# [9] validation loss: 0.6567102372646332 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [10] train loss: 0.39030991196632386 accuracy: 0.8720424 f1 score: 0.0
# [10] validation loss: 0.7186310887336731 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [11] train loss: 0.37997368425130845 accuracy: 0.877504 f1 score: 0.0
# [11] validation loss: 0.7369972467422485 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [12] train loss: 0.38408796191215516 accuracy: 0.8730264 f1 score: 0.0
# [12] validation loss: 0.6607823073863983 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [13] train loss: 0.38077614456415176 accuracy: 0.8747904 f1 score: 0.0
# [13] validation loss: 0.6597087681293488 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [14] train loss: 0.383177250623703 accuracy: 0.8721584 f1 score: 0.0
# [14] validation loss: 0.6907481849193573 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [15] train loss: 0.3710265100002289 accuracy: 0.880156 f1 score: 0.0
# [15] validation loss: 0.7206043303012848 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [16] train loss: 0.3718788310885429 accuracy: 0.8781864 f1 score: 0.0
# [16] validation loss: 0.7019832134246826 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [17] train loss: 0.399449360370636 accuracy: 0.8676896 f1 score: 0.0
# [17] validation loss: 0.6534562408924103 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [18] train loss: 0.38335065096616744 accuracy: 0.8728232 f1 score: 0.0
# [18] validation loss: 0.6761915385723114 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [19] train loss: 0.380929608643055 accuracy: 0.8728224 f1 score: 0.0
# [19] validation loss: 0.6824418306350708 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [20] train loss: 0.3871317893266678 accuracy: 0.874428 f1 score: 0.0
# [20] validation loss: 0.7190536558628082 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [21] train loss: 0.39184715449810026 accuracy: 0.8684984 f1 score: 0.0
# [21] validation loss: 0.6720609366893768 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [22] train loss: 0.4011383980512619 accuracy: 0.8655864 f1 score: 0.0
# [22] validation loss: 0.6554180681705475 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [23] train loss: 0.3723038971424103 accuracy: 0.8784472 f1 score: 0.0
# [23] validation loss: 0.6772515773773193 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [24] train loss: 0.3797320261597633 accuracy: 0.8740056 f1 score: 0.0
# [24] validation loss: 0.7065849304199219 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [25] train loss: 0.37890643924474715 accuracy: 0.874684 f1 score: 0.0
# [25] validation loss: 0.6817440092563629 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [26] train loss: 0.3755806922912598 accuracy: 0.8767536 f1 score: 0.0
# [26] validation loss: 0.6754350960254669 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [27] train loss: 0.3746006637811661 accuracy: 0.8768376 f1 score: 0.0
# [27] validation loss: 0.7074039876461029 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [28] train loss: 0.3759079173207283 accuracy: 0.8764288 f1 score: 0.0
# [28] validation loss: 0.5263141393661499 accuracy: 0.713355 f1 score: 0.05846704659298067
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [29] train loss: 0.5201933294534683 accuracy: 0.8271264 f1 score: 0.09027684224706993
# [29] validation loss: 0.735470175743103 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [30] train loss: 0.3819635257124901 accuracy: 0.8775528 f1 score: 0.0
# [30] validation loss: 0.7303286194801331 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [31] train loss: 0.3734998732805252 accuracy: 0.8808072 f1 score: 0.0
# [31] validation loss: 0.66756272315979 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [32] train loss: 0.40167016685009005 accuracy: 0.8735112 f1 score: 0.0
# [32] validation loss: 0.7265029549598694 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [33] train loss: 0.3712885305285454 accuracy: 0.8792552 f1 score: 0.0
# [33] validation loss: 0.6699297726154327 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [34] train loss: 0.38521355837583543 accuracy: 0.8731944 f1 score: 0.0
# [34] validation loss: 0.6892220973968506 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [35] train loss: 0.3631473213434219 accuracy: 0.8830664 f1 score: 0.0
# [35] validation loss: 0.6955355107784271 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [36] train loss: 0.384222985804081 accuracy: 0.8727072 f1 score: 0.0
# [36] validation loss: 0.6895797848701477 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [37] train loss: 0.3902009978890419 accuracy: 0.8690976 f1 score: 0.0
# [37] validation loss: 0.6789789199829102 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [38] train loss: 0.374628646671772 accuracy: 0.8775872 f1 score: 0.0
# [38] validation loss: 0.6891462802886963 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [39] train loss: 0.3827287584543228 accuracy: 0.8743448 f1 score: 0.0
# [39] validation loss: 0.681505560874939 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [40] train loss: 0.37745323926210406 accuracy: 0.8751536 f1 score: 0.0
# [40] validation loss: 0.6940649747848511 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [41] train loss: 0.38970359563827517 accuracy: 0.8700728 f1 score: 0.0
# [41] validation loss: 0.7155029773712158 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [42] train loss: 0.3999477714300156 accuracy: 0.8641504 f1 score: 0.0
# [42] validation loss: 0.6661418080329895 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [43] train loss: 0.3843954786658287 accuracy: 0.8731248 f1 score: 0.0
# [43] validation loss: 0.6643148362636566 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [44] train loss: 0.37725602388381957 accuracy: 0.8752872 f1 score: 0.0
# [44] validation loss: 0.6923194527626038 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [45] train loss: 0.3890714183449745 accuracy: 0.8723952 f1 score: 0.0
# [45] validation loss: 0.7311584055423737 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [46] train loss: 0.3845962569117546 accuracy: 0.8720712 f1 score: 0.0
# [46] validation loss: 0.672578364610672 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [47] train loss: 0.3816315621137619 accuracy: 0.8761296 f1 score: 0.0
# [47] validation loss: 0.6545107662677765 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [48] train loss: 0.3835918739438057 accuracy: 0.871248 f1 score: 0.0
# [48] validation loss: 0.6960888206958771 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [49] train loss: 0.37243549078702926 accuracy: 0.8776088 f1 score: 0.0
# [49] validation loss: 0.7080971002578735 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [50] train loss: 0.3738256126642227 accuracy: 0.8762736 f1 score: 0.0
# [50] validation loss: 0.6993963420391083 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [51] train loss: 0.38148950040340424 accuracy: 0.8729128 f1 score: 0.0
# [51] validation loss: 0.6794452667236328 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [52] train loss: 0.37701423466205597 accuracy: 0.8753864 f1 score: 0.0
# [52] validation loss: 0.691804826259613 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [53] train loss: 0.37964240461587906 accuracy: 0.8754552 f1 score: 0.0
# [53] validation loss: 0.6599306762218475 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [54] train loss: 0.3882953360676765 accuracy: 0.867684 f1 score: 0.0
# [54] validation loss: 0.6798205077648163 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [55] train loss: 0.38912607729434967 accuracy: 0.8692512 f1 score: 0.0
# [55] validation loss: 0.6800492107868195 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [56] train loss: 0.37455909699201584 accuracy: 0.8738144 f1 score: 0.0
# [56] validation loss: 0.6729676723480225 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [57] train loss: 0.3759430721402168 accuracy: 0.8757008 f1 score: 0.0
# [57] validation loss: 0.612765371799469 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [58] train loss: 0.3472363010048866 accuracy: 0.877532 f1 score: 0.0
# [58] validation loss: 0.65304234623909 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [59] train loss: 0.3478385031223297 accuracy: 0.8822488 f1 score: 0.16414053937408074
# [59] validation loss: 0.4985130876302719 accuracy: 0.803605 f1 score: 0.6709006057660888
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [60] train loss: 0.36631778031587603 accuracy: 0.8781248 f1 score: 1.3128011237577621e-05
# [60] validation loss: 0.685560941696167 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [61] train loss: 0.3549340061843395 accuracy: 0.8731952 f1 score: 0.0
# [61] validation loss: 0.5806755423545837 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [62] train loss: 0.3434359490871429 accuracy: 0.8708352 f1 score: 0.0
# [62] validation loss: 0.523192822933197 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [63] train loss: 0.3013945840299129 accuracy: 0.8739664 f1 score: 0.09420098202683899
# [63] validation loss: 0.47606535255908966 accuracy: 0.8199 f1 score: 0.6192549997885924
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [64] train loss: 0.2929484203457832 accuracy: 0.8811408 f1 score: 0.27037273486225016
# [64] validation loss: 0.5433401465415955 accuracy: 0.750155 f1 score: 0.6408544342463685
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [65] train loss: 0.2678873911499977 accuracy: 0.8856992 f1 score: 0.3568895050503232
# [65] validation loss: 0.601241409778595 accuracy: 0.71632 f1 score: 0.6003099682986968
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# ...
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [98] train loss: 0.2276593256741762 accuracy: 0.9055328 f1 score: 0.6391561037024361
# [98] validation loss: 0.6946858465671539 accuracy: 0.6229 f1 score: 0.5404245984351768
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [99] train loss: 0.2046222798526287 accuracy: 0.9099912 f1 score: 0.6642394797862087
# [99] validation loss: 0.7978652715682983 accuracy: 0.57412 f1 score: 0.5213110331804693
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [100] train loss: 0.20459981858730317 accuracy: 0.9166248 f1 score: 0.6561688622319876
# [100] validation loss: 0.8451818823814392 accuracy: 0.56096 f1 score: 0.5176603715544422
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [101] train loss: 0.19175718761980534 accuracy: 0.922368 f1 score: 0.6839582084885751
# [101] validation loss: 0.7550705075263977 accuracy: 0.60032 f1 score: 0.5206236881559221
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [102] train loss: 0.20008002296090127 accuracy: 0.9229672 f1 score: 0.6770004863894806
# [102] validation loss: 0.7563496232032776 accuracy: 0.608785 f1 score: 0.5155682134786242
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [103] train loss: 0.201562736928463 accuracy: 0.9133872 f1 score: 0.6584754958865391
# [103] validation loss: 0.8180754482746124 accuracy: 0.593795 f1 score: 0.5225919810073397
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [104] train loss: 0.1906236108392477 accuracy: 0.9237984 f1 score: 0.6790981922068822
# [104] validation loss: 0.843362420797348 accuracy: 0.57534 f1 score: 0.5183294768839889
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [105] train loss: 0.19017999544739722 accuracy: 0.9248192 f1 score: 0.7033211264048491
# [105] validation loss: 0.9300385117530823 accuracy: 0.5742 f1 score: 0.5182985462978675
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [106] train loss: 0.18725625798106194 accuracy: 0.9250032 f1 score: 0.6959378811074496
# [106] validation loss: 0.804455578327179 accuracy: 0.59457 f1 score: 0.48733608993083216
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [107] train loss: 0.17531627789139748 accuracy: 0.92754 f1 score: 0.6687342961952447
# [107] validation loss: 0.8142823278903961 accuracy: 0.56739 f1 score: 0.5176500758183926
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [108] train loss: 0.1969510145485401 accuracy: 0.919264 f1 score: 0.6708178669049966
# [108] validation loss: 0.8949807584285736 accuracy: 0.555185 f1 score: 0.5171693269580414
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [109] train loss: 0.18826465532183648 accuracy: 0.9206088 f1 score: 0.6618531479254053
# [109] validation loss: 0.8163153827190399 accuracy: 0.580425 f1 score: 0.5191255264892124
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [110] train loss: 0.18533453568816186 accuracy: 0.9250744 f1 score: 0.6895742529954757
# [110] validation loss: 0.824852854013443 accuracy: 0.598025 f1 score: 0.4910388138694218
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [111] train loss: 0.1821396268904209 accuracy: 0.9272424 f1 score: 0.6951616417235079
# [111] validation loss: 0.7847892940044403 accuracy: 0.61014 f1 score: 0.5220546769645702
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [112] train loss: 0.1905447132885456 accuracy: 0.9237176 f1 score: 0.7034259676842449
# [112] validation loss: 0.7861607074737549 accuracy: 0.60447 f1 score: 0.5083835684544156
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [113] train loss: 0.1927202232182026 accuracy: 0.923204 f1 score: 0.6881466826499817
# [113] validation loss: 0.8578359484672546 accuracy: 0.593025 f1 score: 0.519813341041963
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [114] train loss: 0.18498692139983178 accuracy: 0.9254152 f1 score: 0.700324968579942
# [114] validation loss: 0.7177971601486206 accuracy: 0.612015 f1 score: 0.5303271494719002
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [115] train loss: 0.1908114194869995 accuracy: 0.9221416 f1 score: 0.6994004873935564
# [115] validation loss: 0.7707618325948715 accuracy: 0.61356 f1 score: 0.5022604618812709
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [116] train loss: 0.18026720657944678 accuracy: 0.9249296 f1 score: 0.6775548072297437
# [116] validation loss: 0.8617749214172363 accuracy: 0.5652 f1 score: 0.5175161179355726
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [117] train loss: 0.17988996841013433 accuracy: 0.9269808 f1 score: 0.7006153402083497
# [117] validation loss: 0.8375270366668701 accuracy: 0.582005 f1 score: 0.5240727562551593
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [118] train loss: 0.1869668297469616 accuracy: 0.9232216 f1 score: 0.692091256460684
# [118] validation loss: 0.7634777426719666 accuracy: 0.610585 f1 score: 0.5343903007694101
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [119] train loss: 0.18095622211694717 accuracy: 0.928028 f1 score: 0.7107802006680363
# [119] validation loss: 0.7306506931781769 accuracy: 0.60586 f1 score: 0.5319836133705397

# %%
from sklearn.metrics import f1_score

outputs = None
points = None
x = y = None
def test_PointNet(pointnet, test_dataloader, device):
    global outputs, points, x, y
    pointnet.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for idx, (points, labels) in enumerate(test_dataloader):
            points, labels = points.to(device), labels.to(device)
            outputs, _ = pointnet(points)
            _, predicted = torch.max(outputs.data, 2)
            total += labels.size(0) * labels.size(1)
            correct += (predicted == labels).sum().item()
            x = labels.view(-1).to('cpu').numpy()
            y = predicted.view(-1).to('cpu').numpy()
            f1 = f1_score(x, y)
            print('Test F1 score: ', f1)
            # plot_batch(points, predicted)
            # plot_batch(points, labels)
    
test_PointNet(classifier, test_dataloader, device)
# Out:
# F1 score:  0.3525585732602868
# F1 score:  0.4030916278246504

# %%
print(sum(x))
print(sum(y))
print(outputs)
# Out:
# 20070
# 104
# tensor([[[-0.0230, -3.7828],
#          [-0.0230, -3.7828],
#          [-0.0230, -3.7829],
#          ...,
#          [-0.1428, -2.0169],
#          [-0.0367, -3.3232],
#          [-0.0366, -3.3251]],
#
#         [[-0.0293, -3.5457],
#          [-0.0276, -3.6032],
#          [-0.0288, -3.5629],
#          ...,
#          [-0.0307, -3.4981],
#          [-0.0309, -3.4912],
#          [-0.0318, -3.4639]],
#
#         [[-0.0360, -3.3428],
#          [-0.0362, -3.3377],
#          [-0.0384, -3.2799],
#          ...,
#          [-0.4682, -0.9839],
#          [-0.4531, -1.0096],
#          [-0.7718, -0.6202]]])

# %%
print(f"Labels has {sum(x == 0)} zeroes and {sum(x == 1)} ones")
print(f"Predictions has {sum(y == 0)} zeroes and {sum(y == 1)} ones")


# writer.add_graph(model, points)
# writer.flush()
# writer.close()
# Out:
# Labels has 54930 zeroes and 20070 ones
# Predictions has 74896 zeroes and 104 ones

# %% [markdown]
# 73.4029268292683% on roofs (5)
# 86.77414634146342% on trees (8)
