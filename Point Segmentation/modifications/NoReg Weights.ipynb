# %%
import torch
from torch import optim
from torch import nn
import torch.nn.init as init
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
# from torchvision.transforms import ToTensorfrom
from torch.utils.tensorboard import SummaryWriter

import matplotlib.pyplot as plt
import numpy as np
import os

from scipy.spatial import KDTree

# %%
class KDTreeDataset(Dataset):
    def __init__(self, pts_file, split=0):
        points = np.loadtxt(pts_file, delimiter=' ')
        points = np.delete(points, -2, 1)
        points = np.delete(points, -2, 1)
        # points = np.delete(points, -2, 1)

        if split == 1:
            points = points[:len(points)//2]
        elif split == 2:
            points = points[len(points)//2:]

        print('file points shape', points.shape)
        
        self.dim_scalars = []
        for i in range(4):
            dim_min, dim_max = min(points[:,i]), max(points[:,i])
            points[:,i] = (points[:,i] - dim_min) / (dim_max - dim_min)
            self.dim_scalars.append(dim_max - dim_min)
        self.data = points

        self.tree = KDTree(self.data[:, :3])
        
    def __len__(self):
        return len(self.data) // 15000
        
    def __getitem__(self, idx):
        # Return batches of 25000 points
        # print('Starting point', self.data[idx * 10000, :3])
        noisy_point = self.data[idx * 15000, :3] + np.random.normal(0, 0.01, 3)[0]
        # print('Noisy point', noisy_point)
        
        _, indicies = self.tree.query(noisy_point, k=25000)

        xyzirn = self.data[indicies, :-1]  # x, y, z, ***intensity, return number, number of returns***
        label = self.data[indicies, -1] == 5

        xyzirn = torch.from_numpy(xyzirn.T).float() # intensity, z, y, x from top to bottom? or other way around
        label = torch.tensor(label).long()
        
        # print(xyzirn.size(), label.size())

        return xyzirn, label

class NormalDataset(Dataset):
    def __init__(self, pts_file, split=0):
        points = np.loadtxt(pts_file, delimiter=' ')
        points = np.delete(points, -2, 1)
        points = np.delete(points, -2, 1)
        # points = np.delete(points, -2, 1)

        if split == 1:
            points = points[:len(points)//2]
        elif split == 2:
            points = points[len(points)//2:]

        print(points.shape)
        # do i need to min max intensity, return number, number of returns, etc.? probably not
        self.dim_scalars = []
        for i in range(4):
            dim_min, dim_max = min(points[:,i]), max(points[:,i])
            points[:,i] = (points[:,i] - dim_min) / (dim_max - dim_min)
            self.dim_scalars.append(dim_max - dim_min)
        self.data = points
        
    def __len__(self):
        return len(self.data) // 25000
        
    def __getitem__(self, idx):
        # Return batches of 25000 points
        xyzirn = self.data[idx * 25000: (idx + 1) * 25000, :-1]  # x, y, z, ***intensity, return number, number of returns***
        label = self.data[idx * 25000: (idx + 1) * 25000, -1] == 5

        xyzirn = torch.from_numpy(xyzirn.T).float() # intensity, z, y, x from top to bottom
        label = torch.tensor(label).long()
        
        return xyzirn, label


data_folder = os.path.join(os.getcwd(), r"data\Point Cloud")
training_data = KDTreeDataset(os.path.join(data_folder, r"Traininig.pts"))
validation_data = NormalDataset(os.path.join(data_folder, r"Testing.pts"), split=1)
testing_data = NormalDataset(os.path.join(data_folder, r"Testing.pts"), split=2)
train_dataloader = DataLoader(training_data, batch_size=5, shuffle=True) # can/should i use shuffle, try lowering it?
validation_dataloader = DataLoader(validation_data, batch_size=5, shuffle=False)
test_dataloader = DataLoader(testing_data, batch_size=5, shuffle=False)

num_classes = 2
# Out:
# file points shape (753876, 5)
# (205861, 5)
# (205861, 5)

# %%
print(len(training_data))
print(len(train_dataloader))
# Out:
# 50
# 10

# %%
for i, data in enumerate(train_dataloader):
    print(data[0].size())
# Out:
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])

# %%
import open3d as o3d
import numpy as np
import copy
from collections import Counter

def plot_view(entire_view = True):
    # Assuming pc is your point cloud data, in shape (N, 3)
    pc_num = 2

    if entire_view:
        pc = training_data.data[:, :3]
        labels = training_data.data[:, -1] == 5
    else:
        pc, labels = training_data[pc_num]
        pc = pc.T.numpy()[:, :3]
        labels = labels.numpy()

    pc = copy.deepcopy(pc)
    for i in range(3):
        pc[:, i] *= training_data.dim_scalars[i]

    print(Counter(labels), len(labels))

    # Define colors for each label
    color_map = {0: [0.5, 0.5, 0.5],  # Gray color for label 0
                1: [1.0, 0.0, 0.0]}  # Red color for label 1

    # Map each label to a color
    colors = np.array([color_map[label] for label in labels])

    # Create point cloud
    point_cloud = o3d.geometry.PointCloud()
    point_cloud.points = o3d.utility.Vector3dVector(pc)
    point_cloud.colors = o3d.utility.Vector3dVector(colors)

    # Visualize the point cloud
    o3d.visualization.draw_geometries([point_cloud])
# plot_view(entire_view = False)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
def plot_batch(data, labels):
    pc, labels = data.transpose(1,2).reshape(-1, 4).numpy()[:, :3], labels.view(-1).numpy()
    # print(labels.shape)
    pc = copy.deepcopy(pc)
    for i in range(3):
        pc[:, i] *= training_data.dim_scalars[i]

    print(Counter(list(labels)), len(labels))

    # Define colors for each label
    color_map = {0: [0.5, 0.5, 0.5],  # Gray color for label 0
                1: [1.0, 0.0, 0.0]}  # Red color for label 1

    # Map each label to a color
    colors = np.array([color_map[label] for label in labels])

    # Create point cloud
    point_cloud = o3d.geometry.PointCloud()
    point_cloud.points = o3d.utility.Vector3dVector(pc)
    point_cloud.colors = o3d.utility.Vector3dVector(colors)

    # Visualize the point cloud
    o3d.visualization.draw_geometries([point_cloud])
# for i, data in enumerate(train_dataloader):
#     print(data[0].size())
#     plot_batch(*data)
#     break

# %%
# Get cpu, gpu or mps device for training.\
try:
    device = (
        "cuda"
        if torch.cuda.is_available()
        else "mps"
        if torch.backends.mps.is_available()
        else "cpu"
    )
except:
    device = 'cpu'
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
class STNkd(nn.Module):
    def __init__(self, k=64):
        super(STNkd, self).__init__()
        self.mlp1 = nn.Sequential(torch.nn.Conv1d(k, 64, 1), nn.Identity(64), nn.GELU())
        self.mlp2 = nn.Sequential(torch.nn.Conv1d(64, 128, 1), nn.Identity(128), nn.GELU())
        self.mlp3 = nn.Sequential(torch.nn.Conv1d(128, 1024, 1), nn.Identity(1024), nn.GELU())
        self.mlp4 = nn.Sequential(nn.Linear(1024, 512), nn.Identity(512), nn.GELU())
        self.mlp5 = nn.Sequential(nn.Linear(512, 256), nn.Identity(256), nn.GELU())
        self.fc = nn.Linear(256, k*k)

        self.k = k

    def forward(self, x):
        batchsize = x.size()[0]
        x = self.mlp1(x)
        x = self.mlp2(x)
        x = self.mlp3(x)

        x = torch.max(x, 2, keepdim=True)[0]
        x = x.view(-1, 1024)

        x = self.mlp4(x)
        x = self.mlp5(x)
        x = self.fc(x)

        iden = torch.eye(self.k, requires_grad=True).repeat(batchsize,1,1)
        if x.is_cuda:
            iden = iden.cuda()
        x = x.view(-1, self.k, self.k) + iden

        return x
    
class PoinNet(nn.Module):
    def __init__(self, input_dim=6, num_classes=2):
        super().__init__()

        # Should GELU be after LayerNorm?
        self.stn1 = STNkd(k=input_dim)
        self.mlp1 = nn.Sequential(nn.Conv1d(input_dim, 64, kernel_size=1), nn.Identity(64), nn.GELU())
        self.mlp2 = nn.Sequential(nn.Conv1d(64, 64, kernel_size=1), nn.Identity(64), nn.GELU())
        
        self.stn2 = STNkd(k=64)
        self.mlp3 = nn.Sequential(nn.Conv1d(64, 64, kernel_size=1), nn.Identity(64), nn.GELU())
        self.mlp4 = nn.Sequential(nn.Conv1d(64, 128, kernel_size=1), nn.Identity(128), nn.GELU())
        self.mlp5 = nn.Sequential(nn.Conv1d(128, 1024, kernel_size=1), nn.Identity(1024), nn.GELU())
        
        self.mlp6 = nn.Sequential(nn.Linear(1088, 512), nn.Identity(512), nn.GELU())
        self.mlp7 = nn.Sequential(nn.Linear(512, 256), nn.Identity(256), nn.GELU())
        self.mlp8 = nn.Sequential(nn.Linear(256, 128), nn.Identity(128), nn.GELU())
        self.fc = nn.Linear(128, num_classes)

        self.debug = nn.Conv1d(input_dim, num_classes, 1)

    def initialize_weights(self):
        for module in self.modules():
            if isinstance(module, nn.Linear) or isinstance(module, nn.Conv1d):
                init.kaiming_uniform_(module.weight, nonlinearity='relu')
                init.constant_(module.bias, 0)
                
    def forward(self, x):
        n_pts = x.size()[2]

        trans6x6 = self.stn1(x) 
        x = x.transpose(2, 1)
        x = torch.bmm(x, trans6x6)
        x = x.transpose(2, 1)

        x = self.mlp1(x)
        # print(1, x.size())
        x = self.mlp2(x)
        # print(2, x.size())
        
        
        trans64x64 = self.stn2(x)
        x = x.transpose(2, 1)
        x = torch.bmm(x, trans64x64)
        local_features = x.transpose(2, 1)
        
        x = self.mlp3(local_features)
        # print(3, x.size())
        x = self.mlp4(x)
        # print(4, x.size())
        x = self.mlp5(x)
        # print(5, x.size())
        x = torch.max(x, 2)[0]
        # print(6, x.size())
        
        # FOR CLASSIFICATION
        # x = self.mlp6(x)
        # print(6, x.size())
        # x = self.mlp7(x)
        # print(7, x.size())
        # x = self.fc(x)
        # print(8, x.size())
        # return F.log_softmax(x, dim=1)

        global_features = x.unsqueeze(2).repeat(1, 1, n_pts)
        # print(7, global_features.size())
        x = torch.cat([local_features, global_features], 1)
        # print(8, x.size())

        x = x.transpose(2, 1)
        x = self.mlp6(x)
        # print(9, x.size())
        x = self.mlp7(x)
        # print(10, x.size())
        x = self.mlp8(x)
        # print(11, x.size())
        x = self.fc(x)
        # print(12, x.size())

        # x = x.view(-1, 2)
        # print(13, x.size())
        x = F.log_softmax(x, dim=-1)
        # print(14, x.size())

        return x, trans64x64

# model = PoinNet(input_dim=6, num_classes=2).to(device)

# %%
def feature_transform_regularizer(trans):
    d = trans.size(1)
    I = torch.eye(d).unsqueeze(0).to(device)
    loss = torch.linalg.norm(I - torch.bmm(trans, trans.transpose(2,1)), dim=(1,2))
    loss = torch.mean(loss)
    return loss

# %% [markdown]
# ## Online Code

# %%
from sklearn.metrics import f1_score
from collections import Counter


writer = SummaryWriter()
classifier = PoinNet(input_dim=4, num_classes=2).to(device)
classifier.initialize_weights()

optimizer = optim.Adam(classifier.parameters(), lr=0.0005, betas=(0.9, 0.999))

num_batch = len(training_data)

for epoch in range(120):
    classifier.train()
    train_loss, train_f1, train_acc = 0.0, 0.0, 0.0
    predictions, labels = np.array([]), np.array([])
    for i, data in enumerate(train_dataloader, 1):
        points, target = data
        points, target = points.to(device), target.to(device)
        optimizer.zero_grad()
        pred, trans_feat = classifier(points)
        pred = pred.view(-1, num_classes)
        target = target.view(-1, 1).squeeze()
        print(f'Iteration {i}', pred.size(), target.size())

        loss = F.nll_loss(pred, target)
        loss += feature_transform_regularizer(trans_feat) * 0.001
        loss.backward()
        optimizer.step()
        train_loss += float(loss) # JUST USING LOSS ACCUMULATES HISTORY

        predictions = np.append(predictions, pred.max(1)[1].cpu())
        labels = np.append(labels, target.cpu())

    train_f1 = f1_score(predictions, labels)
    train_acc = sum(predictions == labels)/float(len(labels))
    train_loss /= len(train_dataloader)


    classifier.eval()
    valid_loss, valid_f1, valid_acc = 0.0, 0.0, 0.0
    predictions, labels = np.array([]), np.array([])
    with torch.no_grad():
        for i, data in enumerate(validation_dataloader):
            points, target = data
            points, target = points.to(device), target.to(device)
            pred,  trans_feat = classifier(points)
            pred = pred.view(-1, num_classes)
            target = target.view(-1, 1).squeeze()

            loss = F.nll_loss(pred, target)
            loss += feature_transform_regularizer(trans_feat) * 0.001
            valid_loss += float(loss)

            predictions = np.append(predictions, pred.max(1)[1].cpu())
            labels = np.append(labels, target.cpu())

    valid_f1 = f1_score(predictions, labels)
    valid_acc = sum(predictions == labels)/float(len(labels))
    valid_loss /= len(validation_dataloader)


    writer.add_scalars('losses', {'training':train_loss, 'validation':valid_loss}, global_step=epoch)
    writer.add_scalars('f1 scores', {'training':train_f1, 'validation':valid_f1}, global_step=epoch)

    print(f'[{epoch}] train loss: {train_loss} accuracy: {train_acc} f1 score: {train_f1}')
    print(f'[{epoch}] validation loss: {valid_loss} accuracy: {valid_acc} f1 score: {valid_f1}')
    print()

writer.flush()
writer.close()
# Out:
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [0] train loss: 12.74721855521202 accuracy: 0.5935912 f1 score: 0.1591546708112161
# [0] validation loss: 7.159364700317383 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [1] train loss: 1.6290291547775269 accuracy: 0.87922 f1 score: 0.0
# [1] validation loss: 2.507637858390808 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [2] train loss: 0.5204389840364456 accuracy: 0.8107696 f1 score: 0.13533411317444072
# [2] validation loss: 0.7373266816139221 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [3] train loss: 0.40086183696985245 accuracy: 0.8720712 f1 score: 0.0
# [3] validation loss: 0.8323069214820862 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [4] train loss: 0.37655178308486936 accuracy: 0.8746448 f1 score: 0.0
# [4] validation loss: 1.0153911113739014 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [5] train loss: 0.3443427115678787 accuracy: 0.8821048 f1 score: 0.0
# [5] validation loss: 0.9567371904850006 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [6] train loss: 0.3429365575313568 accuracy: 0.8774392 f1 score: 0.0
# [6] validation loss: 0.8358543217182159 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [7] train loss: 0.32705454528331757 accuracy: 0.8721352 f1 score: 0.0
# [7] validation loss: 0.7865569591522217 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [8] train loss: 0.30878317132592203 accuracy: 0.8705928 f1 score: 0.0
# [8] validation loss: 0.7325891852378845 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [9] train loss: 0.2788760744035244 accuracy: 0.882504 f1 score: 0.0
# [9] validation loss: 0.7482496500015259 accuracy: 0.705415 f1 score: 0.05510560839093547
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [10] train loss: 0.2651596039533615 accuracy: 0.890224 f1 score: 0.3347038118048619
# [10] validation loss: 0.7730917930603027 accuracy: 0.67826 f1 score: 0.305502190946964
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [11] train loss: 0.2689882680773735 accuracy: 0.9046392 f1 score: 0.4807074865494783
# [11] validation loss: 0.8000253140926361 accuracy: 0.650705 f1 score: 0.36627205515489636
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [12] train loss: 0.26947330832481386 accuracy: 0.893136 f1 score: 0.4248686816498751
# [12] validation loss: 0.8781628012657166 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [13] train loss: 0.25160178169608116 accuracy: 0.9008432 f1 score: 0.48417302714265503
# [13] validation loss: 0.9773682057857513 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [14] train loss: 0.24813367798924446 accuracy: 0.909656 f1 score: 0.5584946673755982
# [14] validation loss: 0.8628283739089966 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [15] train loss: 0.24942061975598334 accuracy: 0.89596 f1 score: 0.44376962096781086
# [15] validation loss: 0.9509422183036804 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [16] train loss: 0.24413880258798598 accuracy: 0.9066768 f1 score: 0.5851535217177931
# [16] validation loss: 1.0439733862876892 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [17] train loss: 0.24297091215848923 accuracy: 0.8976088 f1 score: 0.5100580707644133
# [17] validation loss: 1.1488280296325684 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [18] train loss: 0.2314336210489273 accuracy: 0.9090648 f1 score: 0.45035661613597355
# [18] validation loss: 1.0964708924293518 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [19] train loss: 0.24283299893140792 accuracy: 0.8985592 f1 score: 0.486421463201254
# [19] validation loss: 1.0221266746520996 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [20] train loss: 0.23698317855596543 accuracy: 0.903964 f1 score: 0.5103581611051968
# [20] validation loss: 1.0397199094295502 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [21] train loss: 0.2270047627389431 accuracy: 0.9132464 f1 score: 0.5275599470235606
# [21] validation loss: 1.0360203385353088 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [22] train loss: 0.23415006399154664 accuracy: 0.9108272 f1 score: 0.622336064185183
# [22] validation loss: 1.2161268591880798 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [23] train loss: 0.237197645008564 accuracy: 0.8981048 f1 score: 0.5380410931577898
# [23] validation loss: 1.0710591673851013 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [24] train loss: 0.23099408484995365 accuracy: 0.909844 f1 score: 0.608400137604637
# [24] validation loss: 1.03434818983078 accuracy: 0.70942 f1 score: 0.00927378111148994
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [25] train loss: 0.23217764496803284 accuracy: 0.9048792 f1 score: 0.5035220824338488
# [25] validation loss: 1.1067121028900146 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [26] train loss: 0.22686676755547525 accuracy: 0.9119904 f1 score: 0.573884279594382
# [26] validation loss: 1.256438672542572 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [27] train loss: 0.2319229006767273 accuracy: 0.9150776 f1 score: 0.6529303101142698
# [27] validation loss: 1.311669111251831 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [28] train loss: 0.22212726324796678 accuracy: 0.9070256 f1 score: 0.5532654237939651
# [28] validation loss: 1.4854499697685242 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [29] train loss: 0.22741897478699685 accuracy: 0.9101104 f1 score: 0.6187732833906724
# [29] validation loss: 1.4838257431983948 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [30] train loss: 0.2277658350765705 accuracy: 0.9132304 f1 score: 0.5909471476953015
# [30] validation loss: 1.5182881951332092 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [31] train loss: 0.2219421610236168 accuracy: 0.9164048 f1 score: 0.6169181587552975
# [31] validation loss: 1.380531370639801 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [32] train loss: 0.22321319580078125 accuracy: 0.9125744 f1 score: 0.6013293642107721
# [32] validation loss: 1.3149316906929016 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [33] train loss: 0.22395739778876306 accuracy: 0.9112448 f1 score: 0.6128744102950618
# [33] validation loss: 1.086824357509613 accuracy: 0.7083 f1 score: 3.428062116485551e-05
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [34] train loss: 0.2230665937066078 accuracy: 0.9088752 f1 score: 0.6020723288896341
# [34] validation loss: 1.1411187648773193 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [35] train loss: 0.21524345949292184 accuracy: 0.9119456 f1 score: 0.6005545232841714
# [35] validation loss: 0.9347887933254242 accuracy: 0.715865 f1 score: 0.05258331805071607
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [36] train loss: 0.2159130960702896 accuracy: 0.917372 f1 score: 0.6010390714023601
# [36] validation loss: 1.092459350824356 accuracy: 0.712695 f1 score: 0.030635828398873088
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [37] train loss: 0.21341752260923386 accuracy: 0.9197144 f1 score: 0.6399555133011642
# [37] validation loss: 0.9232961237430573 accuracy: 0.71791 f1 score: 0.06546297830048037
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [38] train loss: 0.21902743726968765 accuracy: 0.9152016 f1 score: 0.641027898754411
# [38] validation loss: 1.3332593142986298 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [39] train loss: 0.2208336092531681 accuracy: 0.908716 f1 score: 0.5420578001276243
# [39] validation loss: 0.8686254918575287 accuracy: 0.653325 f1 score: 0.40611911022792485
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [40] train loss: 0.21771156936883926 accuracy: 0.9113816 f1 score: 0.5808387538643752
# [40] validation loss: 0.71795853972435 accuracy: 0.73061 f1 score: 0.2104862108379004
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [41] train loss: 0.22359584867954255 accuracy: 0.9168264 f1 score: 0.6371552316836105
# [41] validation loss: 0.7226656973361969 accuracy: 0.629995 f1 score: 0.43415227215378616
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [42] train loss: 0.2351330816745758 accuracy: 0.9072968 f1 score: 0.5912485229016384
# [42] validation loss: 0.5754689574241638 accuracy: 0.73336 f1 score: 0.5379256563556016
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [43] train loss: 0.23439982831478118 accuracy: 0.9040648 f1 score: 0.5133177219248299
# [43] validation loss: 0.5447255671024323 accuracy: 0.758625 f1 score: 0.4254686105325796
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [44] train loss: 0.22039137035608292 accuracy: 0.9168968 f1 score: 0.6214556678339899
# [44] validation loss: 0.7306172251701355 accuracy: 0.694985 f1 score: 0.450843948327857
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [45] train loss: 0.2105485662817955 accuracy: 0.9161928 f1 score: 0.6297025503260812
# [45] validation loss: 0.7078129351139069 accuracy: 0.688255 f1 score: 0.4193557399491521
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [46] train loss: 0.20298597142100333 accuracy: 0.9194568 f1 score: 0.6586215198071336
# [46] validation loss: 1.3060932457447052 accuracy: 0.63476 f1 score: 0.4557105388650453
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [47] train loss: 0.22585445791482925 accuracy: 0.9180592 f1 score: 0.6217092628157778
# [47] validation loss: 1.2063961029052734 accuracy: 0.72731 f1 score: 0.13211330362826224
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [48] train loss: 0.22514250576496125 accuracy: 0.9088208 f1 score: 0.6077166655193776
# [48] validation loss: 1.6593531668186188 accuracy: 0.71129 f1 score: 0.021089750110195638
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [49] train loss: 0.20255932491272688 accuracy: 0.9225696 f1 score: 0.662272406886589
# [49] validation loss: 1.6686092615127563 accuracy: 0.71067 f1 score: 0.017321604456067657
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [50] train loss: 0.2075300242751837 accuracy: 0.9190256 f1 score: 0.6697855292605425
# [50] validation loss: 1.4944007396697998 accuracy: 0.70853 f1 score: 0.0016441171433464634
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [51] train loss: 0.250137373059988 accuracy: 0.8969416 f1 score: 0.5278320437776955
# [51] validation loss: 1.3092992305755615 accuracy: 0.715935 f1 score: 0.059247238826977536
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [52] train loss: 0.2262772314250469 accuracy: 0.9203336 f1 score: 0.613436538036031
# [52] validation loss: 1.4534224271774292 accuracy: 0.72547 f1 score: 0.11692614513638702
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [53] train loss: 0.2450340561568737 accuracy: 0.9001696 f1 score: 0.5542394193124339
# [53] validation loss: 1.2235196232795715 accuracy: 0.724965 f1 score: 0.1315187015488577
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [54] train loss: 0.21862058192491532 accuracy: 0.9144744 f1 score: 0.6614349278735768
# [54] validation loss: 1.614508867263794 accuracy: 0.7205 f1 score: 0.08633258147821256
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [55] train loss: 0.20746252462267875 accuracy: 0.915112 f1 score: 0.6212926942431922
# [55] validation loss: 1.4960938096046448 accuracy: 0.72585 f1 score: 0.1378117432462182
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [56] train loss: 0.20207327790558338 accuracy: 0.921036 f1 score: 0.6625596986096248
# [56] validation loss: 1.132928267121315 accuracy: 0.7455 f1 score: 0.2576495639238106
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [57] train loss: 0.20387947857379912 accuracy: 0.9240368 f1 score: 0.6835583934308224
# [57] validation loss: 0.8855224847793579 accuracy: 0.737465 f1 score: 0.2535151196349109
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [58] train loss: 0.20768099129199982 accuracy: 0.921464 f1 score: 0.6823902423242422
# [58] validation loss: 1.1324741542339325 accuracy: 0.733545 f1 score: 0.23585081518232268
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [59] train loss: 0.21356922388076782 accuracy: 0.9196264 f1 score: 0.6554168767427743
# [59] validation loss: 1.3250704854726791 accuracy: 0.743915 f1 score: 0.24013767933178048
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [60] train loss: 0.1969320923089981 accuracy: 0.9203824 f1 score: 0.6432954366245646
# [60] validation loss: 1.953542783856392 accuracy: 0.748275 f1 score: 0.2550641433496589
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [61] train loss: 0.19635468274354934 accuracy: 0.9238456 f1 score: 0.6625426727025868
# [61] validation loss: 2.0280953645706177 accuracy: 0.731225 f1 score: 0.15740552063576657
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [62] train loss: 0.2030058830976486 accuracy: 0.9192208 f1 score: 0.6633885829344073
# [62] validation loss: 2.2052403390407562 accuracy: 0.734125 f1 score: 0.1757730760288305
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [63] train loss: 0.19732694141566753 accuracy: 0.9190296 f1 score: 0.6525006780859779
# [63] validation loss: 2.157651960849762 accuracy: 0.731875 f1 score: 0.16018041438930042
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [64] train loss: 0.19212681427598 accuracy: 0.9251768 f1 score: 0.6955723580781761
# [64] validation loss: 2.0750290751457214 accuracy: 0.73343 f1 score: 0.17788743253662298
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# ...
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [98] train loss: 0.177444676309824 accuracy: 0.9268312 f1 score: 0.6825758758915091
# [98] validation loss: 7.332031548023224 accuracy: 0.53777 f1 score: 0.5360021682610747
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [99] train loss: 0.18265988267958164 accuracy: 0.9233648 f1 score: 0.6695254391654131
# [99] validation loss: 7.004452228546143 accuracy: 0.54731 f1 score: 0.5378592210709
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [100] train loss: 0.1829610750079155 accuracy: 0.9250136 f1 score: 0.7057316602255994
# [100] validation loss: 8.916762351989746 accuracy: 0.52375 f1 score: 0.5303763891491061
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [101] train loss: 0.17718975245952606 accuracy: 0.9255432 f1 score: 0.6958434233015356
# [101] validation loss: 14.089225769042969 accuracy: 0.458805 f1 score: 0.5000715905574363
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [102] train loss: 0.173015034198761 accuracy: 0.9300312 f1 score: 0.7046403955193387
# [102] validation loss: 7.0517566204071045 accuracy: 0.56356 f1 score: 0.5181345434069756
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [103] train loss: 0.17915680408477783 accuracy: 0.9195928 f1 score: 0.649118336027258
# [103] validation loss: 5.933123767375946 accuracy: 0.566495 f1 score: 0.5283349381728766
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [104] train loss: 0.18389336243271828 accuracy: 0.9241488 f1 score: 0.7082466613330051
# [104] validation loss: 3.8867789208889008 accuracy: 0.600855 f1 score: 0.5226594593301722
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [105] train loss: 0.19128736034035682 accuracy: 0.9208584 f1 score: 0.6868992495861805
# [105] validation loss: 1.3514574766159058 accuracy: 0.65883 f1 score: 0.5553513710770513
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [106] train loss: 0.1917074829339981 accuracy: 0.9223328 f1 score: 0.6379002961426855
# [106] validation loss: 1.9461587816476822 accuracy: 0.64575 f1 score: 0.5835096877351391
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [107] train loss: 0.18049128875136375 accuracy: 0.9239384 f1 score: 0.6715264414356834
# [107] validation loss: 3.6785911917686462 accuracy: 0.59811 f1 score: 0.5323271347778529
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [108] train loss: 0.18700822591781616 accuracy: 0.920908 f1 score: 0.683608713601321
# [108] validation loss: 4.40483957529068 accuracy: 0.58425 f1 score: 0.5030718110537387
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [109] train loss: 0.1854730762541294 accuracy: 0.9224128 f1 score: 0.6919108490685913
# [109] validation loss: 4.980402618646622 accuracy: 0.565585 f1 score: 0.4847561156412158
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [110] train loss: 0.18562955558300018 accuracy: 0.9255792 f1 score: 0.6883446681630876
# [110] validation loss: 4.325875163078308 accuracy: 0.566175 f1 score: 0.5135427587869545
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [111] train loss: 0.1914527490735054 accuracy: 0.9254472 f1 score: 0.6898151692368116
# [111] validation loss: 6.384656667709351 accuracy: 0.547515 f1 score: 0.5044762879936922
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [112] train loss: 0.1840112939476967 accuracy: 0.9258968 f1 score: 0.7063619620038484
# [112] validation loss: 4.600975036621094 accuracy: 0.549305 f1 score: 0.4906969517190723
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [113] train loss: 0.18269445449113847 accuracy: 0.9208176 f1 score: 0.6722148628957478
# [113] validation loss: 2.6328125 accuracy: 0.629315 f1 score: 0.5183938884088947
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [114] train loss: 0.17550496011972427 accuracy: 0.9290632 f1 score: 0.6896674821246706
# [114] validation loss: 2.22383813560009 accuracy: 0.653415 f1 score: 0.5471282691214614
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [115] train loss: 0.16762839816510677 accuracy: 0.928936 f1 score: 0.7016304019239683
# [115] validation loss: 2.9330739974975586 accuracy: 0.59442 f1 score: 0.5289047890072364
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [116] train loss: 0.17324285283684732 accuracy: 0.9269792 f1 score: 0.7106757956130341
# [116] validation loss: 4.600567728281021 accuracy: 0.55701 f1 score: 0.4973904558760126
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [117] train loss: 0.17423516660928726 accuracy: 0.9270576 f1 score: 0.691760028667825
# [117] validation loss: 3.7371476888656616 accuracy: 0.56935 f1 score: 0.5393477167948484
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [118] train loss: 0.17233943194150925 accuracy: 0.9285096 f1 score: 0.7140612750979921
# [118] validation loss: 4.005228102207184 accuracy: 0.56649 f1 score: 0.5374906646751307
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [119] train loss: 0.17052974961698056 accuracy: 0.9279448 f1 score: 0.7127562882100248
# [119] validation loss: 4.074339002370834 accuracy: 0.581895 f1 score: 0.5321509497300473

# %%
from sklearn.metrics import f1_score

outputs = None
points = None
x = y = None
def test_PointNet(pointnet, test_dataloader, device):
    global outputs, points, x, y
    pointnet.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for idx, (points, labels) in enumerate(test_dataloader):
            points, labels = points.to(device), labels.to(device)
            outputs, _ = pointnet(points)
            _, predicted = torch.max(outputs.data, 2)
            total += labels.size(0) * labels.size(1)
            correct += (predicted == labels).sum().item()
            x = labels.view(-1).to('cpu').numpy()
            y = predicted.view(-1).to('cpu').numpy()
            f1 = f1_score(x, y)
            print('F1 score: ', f1)
            # plot_batch(points, predicted)
            # plot_batch(points, labels)
    
test_PointNet(classifier, test_dataloader, device)
# Out:
# F1 score:  0.32767448127189436
# F1 score:  0.3600861291569281

# %%
print(sum(x))
print(sum(y))
print(outputs)
# Out:
# 20070
# 16346
# tensor([[[-8.2845e-03, -4.7975e+00],
#          [-8.2437e-03, -4.8024e+00],
#          [-8.2274e-03, -4.8044e+00],
#          ...,
#          [-1.0295e-01, -2.3246e+00],
#          [-4.3892e-03, -5.4308e+00],
#          [-4.5152e-03, -5.4026e+00]],
#
#         [[-4.7847e-03, -5.3447e+00],
#          [-3.5877e-03, -5.6320e+00],
#          [-4.5857e-03, -5.3871e+00],
#          ...,
#          [-7.6904e-02, -2.6034e+00],
#          [-7.7600e-02, -2.5947e+00],
#          [-8.2145e-02, -2.5401e+00]],
#
#         [[-2.5196e-01, -1.5018e+00],
#          [-2.5373e-01, -1.4957e+00],
#          [-2.4049e-01, -1.5429e+00],
#          ...,
#          [-1.5886e+00, -2.2841e-01],
#          [-1.5559e+00, -2.3698e-01],
#          [-2.1179e+00, -1.2815e-01]]], device='cuda:0')

# %%
print(f"Labels has {sum(x == 0)} zeroes and {sum(x == 1)} ones")
print(f"Predictions has {sum(y == 0)} zeroes and {sum(y == 1)} ones")


# writer.add_graph(model, points)
# writer.flush()
# writer.close()
# Out:
# Labels has 54930 zeroes and 20070 ones
# Predictions has 58654 zeroes and 16346 ones

# %% [markdown]
# 73.4029268292683% on roofs (5)
# 86.77414634146342% on trees (8)
