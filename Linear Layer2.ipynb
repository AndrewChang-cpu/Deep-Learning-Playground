# %%
import torch
from torch import optim
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
# from torchvision.transforms import ToTensorfrom
from torch.utils.tensorboard import SummaryWriter

import matplotlib.pyplot as plt
import numpy as np
import os

from scipy.spatial import KDTree

# %%
class KDTreeDataset(Dataset):
    def __init__(self, pts_file, split=0):
        points = np.loadtxt(pts_file, delimiter=' ')
        points = np.delete(points, -2, 1)
        points = np.delete(points, -2, 1)
        # points = np.delete(points, -2, 1)

        if split == 1:
            points = points[:len(points)//2]
        elif split == 2:
            points = points[len(points)//2:]

        print('file points shape', points.shape)
        
        self.dim_scalars = []
        for i in range(4):
            dim_min, dim_max = min(points[:,i]), max(points[:,i])
            points[:,i] = (points[:,i] - dim_min) / (dim_max - dim_min)
            self.dim_scalars.append(dim_max - dim_min)
        self.data = points

        self.tree = KDTree(self.data[:, :3])
        
    def __len__(self):
        return len(self.data) // 15000
        
    def __getitem__(self, idx):
        # Return batches of 25000 points
        # print('Starting point', self.data[idx * 10000, :3])
        noisy_point = self.data[idx * 15000, :3] + np.random.normal(0, 0.01, 3)[0]
        # print('Noisy point', noisy_point)
        
        _, indicies = self.tree.query(noisy_point, k=25000)

        xyzirn = self.data[indicies, :-1]  # x, y, z, ***intensity, return number, number of returns***
        label = self.data[indicies, -1] == 5

        xyzirn = torch.from_numpy(xyzirn.T).float() # intensity, z, y, x from top to bottom? or other way around
        label = torch.tensor(label).long()
        
        # print(xyzirn.size(), label.size())

        return xyzirn, label

class NormalDataset(Dataset):
    def __init__(self, pts_file, split=0):
        points = np.loadtxt(pts_file, delimiter=' ')
        points = np.delete(points, -2, 1)
        points = np.delete(points, -2, 1)
        # points = np.delete(points, -2, 1)

        if split == 1:
            points = points[:len(points)//2]
        elif split == 2:
            points = points[len(points)//2:]

        print(points.shape)
        # do i need to min max intensity, return number, number of returns, etc.? probably not
        self.dim_scalars = []
        for i in range(4):
            dim_min, dim_max = min(points[:,i]), max(points[:,i])
            points[:,i] = (points[:,i] - dim_min) / (dim_max - dim_min)
            self.dim_scalars.append(dim_max - dim_min)
        self.data = points
        
    def __len__(self):
        return len(self.data) // 25000
        
    def __getitem__(self, idx):
        # Return batches of 25000 points
        xyzirn = self.data[idx * 25000: (idx + 1) * 25000, :-1]  # x, y, z, ***intensity, return number, number of returns***
        label = self.data[idx * 25000: (idx + 1) * 25000, -1] == 5

        xyzirn = torch.from_numpy(xyzirn.T).float() # intensity, z, y, x from top to bottom
        label = torch.tensor(label).long()
        
        return xyzirn, label


data_folder = os.path.join(os.getcwd(), r"data\Point Cloud")
training_data = KDTreeDataset(os.path.join(data_folder, r"Traininig.pts"))
validation_data = NormalDataset(os.path.join(data_folder, r"Testing.pts"), split=1)
testing_data = NormalDataset(os.path.join(data_folder, r"Testing.pts"), split=2)
train_dataloader = DataLoader(training_data, batch_size=5, shuffle=True) # can/should i use shuffle, try lowering it?
validation_dataloader = DataLoader(validation_data, batch_size=5, shuffle=False)
test_dataloader = DataLoader(testing_data, batch_size=5, shuffle=False)

num_classes = 2
# Out:
# file points shape (753876, 5)
# (205861, 5)
# (205861, 5)

# %%
print(len(training_data))
print(len(train_dataloader))
# Out:
# 50
# 10

# %%
for i, data in enumerate(train_dataloader):
    print(data[0].size())
# Out:
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])
# torch.Size([5, 4, 25000])

# %%
import open3d as o3d
import numpy as np
import copy
from collections import Counter

def plot_view(entire_view = True):
    # Assuming pc is your point cloud data, in shape (N, 3)
    pc_num = 2

    if entire_view:
        pc = training_data.data[:, :3]
        labels = training_data.data[:, -1] == 5
    else:
        pc, labels = training_data[pc_num]
        pc = pc.T.numpy()[:, :3]
        labels = labels.numpy()

    pc = copy.deepcopy(pc)
    for i in range(3):
        pc[:, i] *= training_data.dim_scalars[i]

    print(Counter(labels), len(labels))

    # Define colors for each label
    color_map = {0: [0.5, 0.5, 0.5],  # Gray color for label 0
                1: [1.0, 0.0, 0.0]}  # Red color for label 1

    # Map each label to a color
    colors = np.array([color_map[label] for label in labels])

    # Create point cloud
    point_cloud = o3d.geometry.PointCloud()
    point_cloud.points = o3d.utility.Vector3dVector(pc)
    point_cloud.colors = o3d.utility.Vector3dVector(colors)

    # Visualize the point cloud
    o3d.visualization.draw_geometries([point_cloud])
# plot_view(entire_view = False)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
def plot_batch(data, labels):
    pc, labels = data.transpose(1,2).reshape(-1, 4).numpy()[:, :3], labels.view(-1).numpy()
    # print(labels.shape)
    pc = copy.deepcopy(pc)
    for i in range(3):
        pc[:, i] *= training_data.dim_scalars[i]

    print(Counter(list(labels)), len(labels))

    # Define colors for each label
    color_map = {0: [0.5, 0.5, 0.5],  # Gray color for label 0
                1: [1.0, 0.0, 0.0]}  # Red color for label 1

    # Map each label to a color
    colors = np.array([color_map[label] for label in labels])

    # Create point cloud
    point_cloud = o3d.geometry.PointCloud()
    point_cloud.points = o3d.utility.Vector3dVector(pc)
    point_cloud.colors = o3d.utility.Vector3dVector(colors)

    # Visualize the point cloud
    o3d.visualization.draw_geometries([point_cloud])
# for i, data in enumerate(train_dataloader):
#     print(data[0].size())
#     plot_batch(*data)
#     break

# %%
# Get cpu, gpu or mps device for training.
# device = (
#     "cuda"
#     if torch.cuda.is_available()
#     else "mps"
#     if torch.backends.mps.is_available()
#     else "cpu"
# )
device = 'cpu'
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
class STNkd(nn.Module):
    def __init__(self, k=64):
        super(STNkd, self).__init__()
        self.mlp1 = nn.Sequential(torch.nn.Conv1d(k, 64, 1), nn.BatchNorm1d(64), nn.GELU())
        self.mlp2 = nn.Sequential(torch.nn.Conv1d(64, 128, 1), nn.BatchNorm1d(128), nn.GELU())
        self.mlp3 = nn.Sequential(torch.nn.Conv1d(128, 1024, 1), nn.BatchNorm1d(1024), nn.GELU())
        self.mlp4 = nn.Sequential(nn.Linear(1024, 512), nn.BatchNorm1d(512), nn.GELU())
        self.mlp5 = nn.Sequential(nn.Linear(512, 256), nn.BatchNorm1d(256), nn.GELU())
        self.fc = nn.Linear(256, k*k)

        self.k = k

    def forward(self, x):
        batchsize = x.size()[0]
        x = self.mlp1(x)
        x = self.mlp2(x)
        x = self.mlp3(x)

        x = torch.max(x, 2, keepdim=True)[0]
        x = x.view(-1, 1024)

        x = self.mlp4(x)
        x = self.mlp5(x)
        x = self.fc(x)

        iden = torch.eye(self.k, requires_grad=True).repeat(batchsize,1,1)
        if x.is_cuda:
            iden = iden.cuda()
        x = x.view(-1, self.k, self.k) + iden

        return x
    
class PoinNet(nn.Module):
    def __init__(self, input_dim=6, num_classes=2):
        super().__init__()

        # Should GELU be after LayerNorm?
        self.stn1 = STNkd(k=input_dim)
        self.mlp1 = nn.Sequential(nn.Conv1d(input_dim, 64, kernel_size=1), nn.BatchNorm1d(64), nn.GELU())
        self.mlp2 = nn.Sequential(nn.Conv1d(64, 64, kernel_size=1), nn.BatchNorm1d(64), nn.GELU())
        
        self.stn2 = STNkd(k=64)
        self.mlp3 = nn.Sequential(nn.Conv1d(64, 64, kernel_size=1), nn.BatchNorm1d(64), nn.GELU())
        self.mlp4 = nn.Sequential(nn.Conv1d(64, 128, kernel_size=1), nn.BatchNorm1d(128), nn.GELU())
        self.mlp5 = nn.Sequential(nn.Conv1d(128, 1024, kernel_size=1), nn.BatchNorm1d(1024), nn.GELU())
        
        self.mlp6 = nn.Sequential(nn.Linear(1088, 512), nn.LayerNorm(512), nn.GELU())
        self.mlp7 = nn.Sequential(nn.Linear(512, 256), nn.LayerNorm(256), nn.GELU())
        self.mlp8 = nn.Sequential(nn.Linear(256, 128), nn.LayerNorm(128), nn.GELU())
        self.fc = nn.Linear(128, num_classes)

        self.debug = nn.Conv1d(input_dim, num_classes, 1)

    def forward(self, x):
        n_pts = x.size()[2]

        trans6x6 = self.stn1(x) 
        x = x.transpose(2, 1)
        x = torch.bmm(x, trans6x6)
        x = x.transpose(2, 1)

        x = self.mlp1(x)
        # print(1, x.size())
        x = self.mlp2(x)
        # print(2, x.size())
        
        
        trans64x64 = self.stn2(x)
        x = x.transpose(2, 1)
        x = torch.bmm(x, trans64x64)
        local_features = x.transpose(2, 1)
        
        x = self.mlp3(local_features)
        # print(3, x.size())
        x = self.mlp4(x)
        # print(4, x.size())
        x = self.mlp5(x)
        # print(5, x.size())
        x = torch.max(x, 2)[0]
        # print(6, x.size())
        
        # FOR CLASSIFICATION
        # x = self.mlp6(x)
        # print(6, x.size())
        # x = self.mlp7(x)
        # print(7, x.size())
        # x = self.fc(x)
        # print(8, x.size())
        # return F.log_softmax(x, dim=1)

        global_features = x.unsqueeze(2).repeat(1, 1, n_pts)
        # print(7, global_features.size())
        x = torch.cat([local_features, global_features], 1)
        # print(8, x.size())

        x = x.transpose(2, 1)
        x = self.mlp6(x)
        # print(9, x.size())
        x = self.mlp7(x)
        # print(10, x.size())
        x = self.mlp8(x)
        # print(11, x.size())
        x = self.fc(x)
        # print(12, x.size())

        # x = x.view(-1, 2)
        # print(x, x.size())
        x = F.log_softmax(x, dim=-1)
        # print(x, x.size())

        return x, trans64x64
        # return x, trans64x64

# model = PoinNet(input_dim=6, num_classes=2).to(device)

# %%
def feature_transform_regularizer(trans):
    d = trans.size(1)
    I = torch.eye(d).unsqueeze(0).to(device)
    loss = torch.linalg.norm(I - torch.bmm(trans, trans.transpose(2,1)), dim=(1,2))
    loss = torch.mean(loss)
    return loss

# %% [markdown]
# ## Online Code

# %%
from sklearn.metrics import f1_score
from collections import Counter


writer = SummaryWriter()
classifier = PoinNet(input_dim=4, num_classes=2).to(device)

optimizer = optim.Adam(classifier.parameters(), lr=0.0005, betas=(0.9, 0.999))

num_batch = len(training_data)

for epoch in range(120):
    classifier.train()
    train_loss, train_f1, train_acc = 0.0, 0.0, 0.0
    predictions, labels = np.array([]), np.array([])
    for i, data in enumerate(train_dataloader, 1):
        points, target = data
        points, target = points.to(device), target.to(device)
        optimizer.zero_grad()
        pred, trans_feat = classifier(points)
        pred = pred.view(-1, num_classes)
        target = target.view(-1, 1).squeeze()
        print(f'Iteration {i}', pred.size(), target.size())

        loss = F.nll_loss(pred, target)
        loss += feature_transform_regularizer(trans_feat) * 0.001
        loss.backward()
        optimizer.step()
        train_loss += float(loss) # JUST USING LOSS ACCUMULATES HISTORY

        predictions = np.append(predictions, pred.max(1)[1].cpu())
        labels = np.append(labels, target.cpu())

    train_f1 = f1_score(predictions, labels)
    train_acc = sum(predictions == labels)/float(len(labels))
    train_loss /= len(train_dataloader)


    classifier.eval()
    valid_loss, valid_f1, valid_acc = 0.0, 0.0, 0.0
    predictions, labels = np.array([]), np.array([])
    with torch.no_grad():
        for i, data in enumerate(validation_dataloader):
            points, target = data
            points, target = points.to(device), target.to(device)
            pred,  trans_feat = classifier(points)
            pred = pred.view(-1, num_classes)
            target = target.view(-1, 1).squeeze()

            loss = F.nll_loss(pred, target)
            loss += feature_transform_regularizer(trans_feat) * 0.001
            valid_loss += float(loss)

            predictions = np.append(predictions, pred.max(1)[1].cpu())
            labels = np.append(labels, target.cpu())

    valid_f1 = f1_score(predictions, labels)
    valid_acc = sum(predictions == labels)/float(len(labels))
    valid_loss /= len(validation_dataloader)


    writer.add_scalars('losses', {'training':train_loss, 'validation':valid_loss}, global_step=epoch)
    writer.add_scalars('f1 scores', {'training':train_f1, 'validation':valid_f1}, global_step=epoch)

    print(f'[{epoch}] train loss: {train_loss} accuracy: {train_acc} f1 score: {train_f1}')
    print(f'[{epoch}] validation loss: {valid_loss} accuracy: {valid_acc} f1 score: {valid_f1}')
    print()

writer.flush()
writer.close()
# Out:
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [0] train loss: 0.5247413635253906 accuracy: 0.8761704 f1 score: 0.0
# [0] validation loss: 0.7387735545635223 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [1] train loss: 0.48863541185855863 accuracy: 0.8677784 f1 score: 0.0
# [1] validation loss: 0.8080556690692902 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [2] train loss: 0.4602268099784851 accuracy: 0.8704024 f1 score: 0.0
# [2] validation loss: 0.7133533954620361 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [3] train loss: 0.4431945413351059 accuracy: 0.87282 f1 score: 0.0
# [3] validation loss: 0.7473804354667664 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [4] train loss: 0.4499430015683174 accuracy: 0.8708216 f1 score: 0.0
# [4] validation loss: 0.7352273464202881 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [5] train loss: 0.40173819214105605 accuracy: 0.8732264 f1 score: 0.0
# [5] validation loss: 0.8055698871612549 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [6] train loss: 0.3717468172311783 accuracy: 0.8580256 f1 score: 0.1400994272756345
# [6] validation loss: 0.9095108509063721 accuracy: 0.692585 f1 score: 0.07384198237553664
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [7] train loss: 0.40026741325855253 accuracy: 0.8724984 f1 score: 0.0
# [7] validation loss: 1.2273353338241577 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [8] train loss: 0.42054418474435806 accuracy: 0.87116 f1 score: 0.0
# [8] validation loss: 1.1160417199134827 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [9] train loss: 0.4219735562801361 accuracy: 0.8746424 f1 score: 0.0
# [9] validation loss: 0.7842268347740173 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [10] train loss: 0.36930652856826784 accuracy: 0.8790376 f1 score: 0.0
# [10] validation loss: 0.714146763086319 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [11] train loss: 0.3862004280090332 accuracy: 0.8729056 f1 score: 0.0
# [11] validation loss: 0.7280551493167877 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [12] train loss: 0.3385850965976715 accuracy: 0.8709992 f1 score: 0.0
# [12] validation loss: 0.7042648792266846 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [13] train loss: 0.3376264959573746 accuracy: 0.8692608 f1 score: 0.005864175000608317
# [13] validation loss: 0.7039716243743896 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [14] train loss: 0.4111555129289627 accuracy: 0.8434352 f1 score: 0.057174790677059745
# [14] validation loss: 0.6985744833946228 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [15] train loss: 0.36364644914865496 accuracy: 0.8763096 f1 score: 0.0
# [15] validation loss: 0.7511235475540161 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [16] train loss: 0.37737288922071455 accuracy: 0.8724288 f1 score: 0.0
# [16] validation loss: 0.7726783156394958 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [17] train loss: 0.3305656731128693 accuracy: 0.872476 f1 score: 0.0
# [17] validation loss: 0.7646374404430389 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [18] train loss: 0.33642269521951673 accuracy: 0.8609424 f1 score: 0.048197389171193275
# [18] validation loss: 0.7362031936645508 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [19] train loss: 0.3179337501525879 accuracy: 0.8720968 f1 score: 0.1751799210668868
# [19] validation loss: 0.7142060101032257 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [20] train loss: 0.3301830068230629 accuracy: 0.873552 f1 score: 0.0007586294095334429
# [20] validation loss: 0.7393617331981659 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [21] train loss: 0.3223856419324875 accuracy: 0.882948 f1 score: 0.0
# [21] validation loss: 0.7033606171607971 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [22] train loss: 0.36491956263780595 accuracy: 0.871296 f1 score: 0.0
# [22] validation loss: 0.7189462780952454 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [23] train loss: 0.3562037467956543 accuracy: 0.881584 f1 score: 0.0
# [23] validation loss: 0.713659793138504 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [24] train loss: 0.3071693375706673 accuracy: 0.8762376 f1 score: 0.0
# [24] validation loss: 0.6850504279136658 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [25] train loss: 0.31948772817850113 accuracy: 0.8786888 f1 score: 0.0
# [25] validation loss: 0.6781123280525208 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [26] train loss: 0.3605735808610916 accuracy: 0.8747368 f1 score: 0.0
# [26] validation loss: 0.6881125271320343 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [27] train loss: 0.37038835436105727 accuracy: 0.872592 f1 score: 0.0
# [27] validation loss: 0.903317391872406 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [28] train loss: 0.3356819599866867 accuracy: 0.8731272 f1 score: 0.0
# [28] validation loss: 0.7217283844947815 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [29] train loss: 0.3266738742589951 accuracy: 0.8721856 f1 score: 0.0
# [29] validation loss: 0.6840302646160126 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [30] train loss: 0.3421531945466995 accuracy: 0.8763968 f1 score: 0.0
# [30] validation loss: 0.7172434628009796 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [31] train loss: 0.30358379483222964 accuracy: 0.8800648 f1 score: 0.382228229292434
# [31] validation loss: 0.8051566779613495 accuracy: 0.477775 f1 score: 0.455797377073097
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [32] train loss: 0.3046280711889267 accuracy: 0.8964952 f1 score: 0.47656961149612215
# [32] validation loss: 0.7766449451446533 accuracy: 0.709695 f1 score: 0.012886992298406976
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [33] train loss: 0.3399291455745697 accuracy: 0.876356 f1 score: 0.0006982924164150444
# [33] validation loss: 0.7952447533607483 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [34] train loss: 0.3163957566022873 accuracy: 0.8800232 f1 score: 0.3188121420233374
# [34] validation loss: 0.7173064351081848 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [35] train loss: 0.27930753827095034 accuracy: 0.8869704 f1 score: 0.33103696443705816
# [35] validation loss: 0.7735892832279205 accuracy: 0.54776 f1 score: 0.4651908090017857
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [36] train loss: 0.28041376918554306 accuracy: 0.8789152 f1 score: 0.5834956906515206
# [36] validation loss: 0.7442990243434906 accuracy: 0.563195 f1 score: 0.43187597141203476
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [37] train loss: 0.32998799383640287 accuracy: 0.8797664 f1 score: 0.0
# [37] validation loss: 0.8084177672863007 accuracy: 0.71989 f1 score: 0.11497630331753554
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [38] train loss: 0.34035691916942595 accuracy: 0.8538728 f1 score: 0.34082157769188853
# [38] validation loss: 0.8060568273067474 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [39] train loss: 0.30156655609607697 accuracy: 0.86946 f1 score: 0.0
# [39] validation loss: 0.6642177999019623 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [40] train loss: 0.3203936696052551 accuracy: 0.8695344 f1 score: 0.0
# [40] validation loss: 0.7246791124343872 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [41] train loss: 0.3441218391060829 accuracy: 0.8789904 f1 score: 0.0
# [41] validation loss: 0.6963644027709961 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [42] train loss: 0.33272041082382203 accuracy: 0.878532 f1 score: 0.0
# [42] validation loss: 0.7036729454994202 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [43] train loss: 0.31400223076343536 accuracy: 0.8730576 f1 score: 0.09772324068598462
# [43] validation loss: 0.6631703972816467 accuracy: 0.73502 f1 score: 0.2327870751056807
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [44] train loss: 0.35965198278427124 accuracy: 0.8687336 f1 score: 0.0003168123800530052
# [44] validation loss: 0.9508389532566071 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [45] train loss: 0.32208858877420427 accuracy: 0.8797464 f1 score: 0.0
# [45] validation loss: 0.7429688572883606 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [46] train loss: 0.3872481003403664 accuracy: 0.874428 f1 score: 0.0
# [46] validation loss: 0.7610019147396088 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [47] train loss: 0.3474032759666443 accuracy: 0.871948 f1 score: 0.0
# [47] validation loss: 0.9210835993289948 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [48] train loss: 0.31274336501955985 accuracy: 0.8809488 f1 score: 0.0
# [48] validation loss: 0.7640676498413086 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [49] train loss: 0.30854521244764327 accuracy: 0.8752368 f1 score: 0.0
# [49] validation loss: 0.71632519364357 accuracy: 0.708295 f1 score: 0.0
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [50] train loss: 0.29245286881923677 accuracy: 0.8830272 f1 score: 0.3266155773340211
# [50] validation loss: 0.7104199826717377 accuracy: 0.733175 f1 score: 0.2169134371285603
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [51] train loss: 0.30402853786945344 accuracy: 0.8899472 f1 score: 0.48018470095675697
# [51] validation loss: 0.6908385157585144 accuracy: 0.728885 f1 score: 0.5688957440549544
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [52] train loss: 0.2697973564267159 accuracy: 0.9143248 f1 score: 0.4914573341564176
# [52] validation loss: 0.59709033370018 accuracy: 0.80058 f1 score: 0.5912100526822869
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [53] train loss: 0.2925419956445694 accuracy: 0.8879336 f1 score: 0.46063630308140724
# [53] validation loss: 0.590171754360199 accuracy: 0.75581 f1 score: 0.3502993215378475
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [54] train loss: 0.3100355163216591 accuracy: 0.8863816 f1 score: 0.39319116937051646
# [54] validation loss: 0.6913867592811584 accuracy: 0.673405 f1 score: 0.5313703966767827
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [55] train loss: 0.28951495736837385 accuracy: 0.884316 f1 score: 0.5432463762622673
# [55] validation loss: 0.6690941452980042 accuracy: 0.74414 f1 score: 0.4481613285883748
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [56] train loss: 0.2794421464204788 accuracy: 0.8946232 f1 score: 0.26276522508101574
# [56] validation loss: 0.6946788728237152 accuracy: 0.750595 f1 score: 0.3401023958512482
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [57] train loss: 0.3320536851882935 accuracy: 0.8934824 f1 score: 0.3877876635170242
# [57] validation loss: 0.8580053746700287 accuracy: 0.74085 f1 score: 0.2651979131223772
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [58] train loss: 0.2884903073310852 accuracy: 0.8936696 f1 score: 0.4823675570839387
# [58] validation loss: 0.7372702360153198 accuracy: 0.73467 f1 score: 0.568484907624252
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [59] train loss: 0.28775993287563323 accuracy: 0.8977784 f1 score: 0.5020595375880224
# [59] validation loss: 0.7848698198795319 accuracy: 0.486935 f1 score: 0.48262787707666316
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [60] train loss: 0.28654430359601973 accuracy: 0.8953888 f1 score: 0.47740806164126254
# [60] validation loss: 0.6227627098560333 accuracy: 0.720865 f1 score: 0.5773723456603203
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [61] train loss: 0.3191810429096222 accuracy: 0.8692912 f1 score: 0.4252516937883873
# [61] validation loss: 0.7440121471881866 accuracy: 0.678325 f1 score: 0.5626890527818373
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [62] train loss: 0.28326171785593035 accuracy: 0.8804976 f1 score: 0.24206691495083363
# [62] validation loss: 0.6176084280014038 accuracy: 0.75284 f1 score: 0.537889127792839
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [63] train loss: 0.2962338477373123 accuracy: 0.8885776 f1 score: 0.5635286743967408
# [63] validation loss: 0.8433459997177124 accuracy: 0.48929 f1 score: 0.4936898353309738
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [64] train loss: 0.2754881590604782 accuracy: 0.9001368 f1 score: 0.5735010232914108
# [64] validation loss: 0.6164747178554535 accuracy: 0.73806 f1 score: 0.5217629445702183
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [65] train loss: 0.317983004450798 accuracy: 0.886028 f1 score: 0.41257602309040314
# ...
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [98] train loss: 0.2389862507581711 accuracy: 0.917288 f1 score: 0.6368815149897447
# [98] validation loss: 0.6049396395683289 accuracy: 0.651765 f1 score: 0.5153406679053325
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [99] train loss: 0.25417151749134065 accuracy: 0.9126224 f1 score: 0.5946694178072024
# [99] validation loss: 0.6031230092048645 accuracy: 0.695075 f1 score: 0.4086876424104329
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [100] train loss: 0.2581621654331684 accuracy: 0.891672 f1 score: 0.5875971542041274
# [100] validation loss: 0.6100846230983734 accuracy: 0.64997 f1 score: 0.37874054879131025
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [101] train loss: 0.2773556917905807 accuracy: 0.8871608 f1 score: 0.4719303040400145
# [101] validation loss: 0.563046008348465 accuracy: 0.69397 f1 score: 0.5579006674178729
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [102] train loss: 0.24156293123960496 accuracy: 0.9158112 f1 score: 0.6318720528355745
# [102] validation loss: 0.5704837143421173 accuracy: 0.68381 f1 score: 0.5352265878790551
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [103] train loss: 0.27589594572782516 accuracy: 0.8886144 f1 score: 0.5613911290322581
# [103] validation loss: 0.6065249145030975 accuracy: 0.699205 f1 score: 0.5807939682384831
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [104] train loss: 0.2256641738116741 accuracy: 0.9250936 f1 score: 0.6633662298441461
# [104] validation loss: 0.6271083056926727 accuracy: 0.66366 f1 score: 0.5642022337971961
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [105] train loss: 0.24080434292554856 accuracy: 0.9032712 f1 score: 0.6359473089951073
# [105] validation loss: 0.6843301951885223 accuracy: 0.58861 f1 score: 0.5293451400329489
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [106] train loss: 0.2865206241607666 accuracy: 0.8768008 f1 score: 0.49529209340434244
# [106] validation loss: 0.6889568865299225 accuracy: 0.578425 f1 score: 0.5343282098298364
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [107] train loss: 0.2414902575314045 accuracy: 0.9145632 f1 score: 0.6344880930379011
# [107] validation loss: 0.614046573638916 accuracy: 0.655485 f1 score: 0.5568454429101574
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [108] train loss: 0.2696852073073387 accuracy: 0.8989872 f1 score: 0.5389901055168133
# [108] validation loss: 0.6907908916473389 accuracy: 0.56996 f1 score: 0.5327328240957048
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [109] train loss: 0.26777424216270446 accuracy: 0.8978992 f1 score: 0.5735878811367782
# [109] validation loss: 0.6331357657909393 accuracy: 0.658875 f1 score: 0.5648055419119852
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [110] train loss: 0.2681011870503426 accuracy: 0.8922496 f1 score: 0.5492882336012637
# [110] validation loss: 0.6208791136741638 accuracy: 0.68425 f1 score: 0.5711375212224108
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [111] train loss: 0.2603160262107849 accuracy: 0.9103064 f1 score: 0.5896742412320349
# [111] validation loss: 0.6562196910381317 accuracy: 0.605715 f1 score: 0.5334043371497885
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [112] train loss: 0.2385621577501297 accuracy: 0.9116136 f1 score: 0.6926374650512581
# [112] validation loss: 0.5918537676334381 accuracy: 0.697925 f1 score: 0.570156028772474
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [113] train loss: 0.23475983664393424 accuracy: 0.9097 f1 score: 0.49683726279470963
# [113] validation loss: 0.566766619682312 accuracy: 0.73359 f1 score: 0.592177573670111
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [114] train loss: 0.2786090299487114 accuracy: 0.8817416 f1 score: 0.6040218477355341
# [114] validation loss: 0.7989583909511566 accuracy: 0.445315 f1 score: 0.4860958628069541
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [115] train loss: 0.25564502030611036 accuracy: 0.8939488 f1 score: 0.5520487676306204
# [115] validation loss: 0.5871957242488861 accuracy: 0.763295 f1 score: 0.4453894726976651
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [116] train loss: 0.2801074288785458 accuracy: 0.8964648 f1 score: 0.38620055110529333
# [116] validation loss: 0.6397870481014252 accuracy: 0.607175 f1 score: 0.5348017881990704
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [117] train loss: 0.25884938836097715 accuracy: 0.912216 f1 score: 0.6007553375733143
# [117] validation loss: 0.6634094417095184 accuracy: 0.570535 f1 score: 0.5193103023723046
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [118] train loss: 0.22354207038879395 accuracy: 0.9205144 f1 score: 0.6691375538217166
# [118] validation loss: 0.6800669133663177 accuracy: 0.58497 f1 score: 0.5259346408215015
#
# Iteration 1 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 2 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 3 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 4 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 5 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 6 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 7 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 8 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 9 torch.Size([125000, 2]) torch.Size([125000])
# Iteration 10 torch.Size([125000, 2]) torch.Size([125000])
# [119] train loss: 0.2564143940806389 accuracy: 0.9009816 f1 score: 0.5541752063019808
# [119] validation loss: 0.7157783806324005 accuracy: 0.579235 f1 score: 0.5385159553174338

# %%
torch.save(classifier, 'base_model.pth')

# %%
from sklearn.metrics import f1_score

outputs = None
points = None
x = y = None
def test_PointNet(pointnet, test_dataloader, device):
    global outputs, points, x, y
    pointnet.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for idx, (points, labels) in enumerate(test_dataloader):
            points, labels = points.to(device), labels.to(device)
            outputs, _ = pointnet(points)
            _, predicted = torch.max(outputs.data, 2)
            total += labels.size(0) * labels.size(1)
            correct += (predicted == labels).sum().item()
            x = labels.view(-1).to('cpu').numpy()
            y = predicted.view(-1).to('cpu').numpy()
            f1 = f1_score(x, y)
            print('F1 score: ', f1)
            plot_batch(points, predicted)
            plot_batch(points, labels)
    
test_PointNet(classifier, test_dataloader, device)
# Out:
# F1 score:  0.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1\ipykernel_9092\1842858222.py in <cell line: 25>()
#      23             plot_batch(points, labels)
#      24
# ---> 25 test_PointNet(classifier, test_dataloader, device)
#
# ~\AppData\Local\Temp\1\ipykernel_9092\1842858222.py in test_PointNet(pointnet, test_dataloader, device)
#      20             f1 = f1_score(x, y)
#      21             print('F1 score: ', f1)
# ---> 22             plot_batch(points, predicted)
#      23             plot_batch(points, labels)
#      24
#
# ~\AppData\Local\Temp\1\ipykernel_9092\3063570382.py in plot_batch(data, labels)
#       1 def plot_batch(data, labels):
# ----> 2     pc, labels = data.transpose(1,2).reshape(-1, 4).numpy()[:, :3], labels.view(-1).numpy()
#       3     # print(labels.shape)
#       4     pc = copy.deepcopy(pc)
#       5     for i in range(3):
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
print(sum(x))
print(sum(y))
print(outputs)
# Out:
# 20070
# 20965
# tensor([[[-0.0199, -3.9263],
#          [-0.0199, -3.9261],
#          [-0.0199, -3.9259],
#          ...,
#          [-0.3394, -1.2456],
#          [-0.1242, -2.1474],
#          [-0.1215, -2.1678]],
#
#         [[-0.1984, -1.7152],
#          [-0.1861, -1.7731],
#          [-0.1867, -1.7700],
#          ...,
#          [-0.0231, -3.7794],
#          [-0.0232, -3.7755],
#          [-0.0233, -3.7693]],
#
#         [[-0.0218, -3.8362],
#          [-0.0219, -3.8333],
#          [-0.0320, -3.4593],
#          ...,
#          [-1.0450, -0.4334],
#          [-1.0428, -0.4346],
#          [-1.0892, -0.4102]]], device='cuda:0')

# %%
print(f"Labels has {sum(x == 0)} zeroes and {sum(x == 1)} ones")
print(f"Predictions has {sum(y == 0)} zeroes and {sum(y == 1)} ones")


# writer.add_graph(model, points)
# writer.flush()
# writer.close()
# Out:
# Labels has 54930 zeroes and 20070 ones
# Predictions has 54035 zeroes and 20965 ones

# %% [markdown]
# 73.4029268292683% on roofs (5)
# 86.77414634146342% on trees (8)
